# %% [markdown]
# # Simulación interactiva de tenis de mesa\nAjuste los parámetros y ejecute la celda siguiente.

# %%
from pathlib import Path\nimport sys\nsys.path.insert(0, str(Path.cwd().parent / 'src'))\nfrom table_tennis_sim import SimulationParameters, run_simulation\nfrom table_tennis_sim.visualization import plot_trajectory\n\nparams = SimulationParameters(initial_velocity_m_s=(4.0, 0.0, 1.5))\nresult = run_simulation(params)\nplot_trajectory(result)
